# %%
import cv2
import mediapipe as mp
import datetime
import numpy as np
import time
import os
import glob
import shutil

# %%
#def check_face_present():
mp_face_detection = mp.solutions.face_detection
face_detection = mp_face_detection.FaceDetection(min_detection_confidence=0.5)

#cap = cv2.VideoCapture(0)
path = "C:\\Users\\99455\\Desktop\\DataScience\\Proctoring Task\\MoreThanOneFace\\*.*"
for file in glob.glob(path):
    
#while cap.isOpened():
    #success, image = cap.read()
    image = cv2.imread(file)
    image = cv2.cvtColor(cv2.flip(image,1), cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    
    rdet = face_detection.process(image)
    
    image.flags.writeable = True
    image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    old_path =  file
    filename = file.split('\\')[-1]
    
    if not rdet.detections:
        x = "face not detected"
        new_path = "C:\\Users\\99455\\Desktop\\DataScience\\Proctoring Task\\FaceNotDetected\\"+filename
        #shutil.move(old_path, new_path)
    else:
        x = "face detected"
        #face_count = 
        new_path = "C:\\Users\\99455\\Desktop\\DataScience\\Proctoring Task\\MoreThanOneFace\\"+filename
        
        if len(rdet.detections) > 1:
            print(filename +' '+ str(len(rdet.detections)))
            #shutil.move(old_path, new_path)
        for detection in rdet.detections:
            bboxC = detection.location_data.relative_bounding_box
            ih, iw, _ = image.shape
            bbox = int(bboxC.xmin * iw), int(bboxC.ymin * ih), int(bboxC.width * iw), int(bboxC.height * ih)
            if bbox[2] * bbox[3] > 5000:
                cv2.rectangle(image, bbox, (255, 0, 255), 2)
        
    cv2.putText(image,x, (20,450), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0),2)  
    cv2.putText(image,filename,(20,50), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0),2)
    cv2.imshow("Face Detection", image)  
    cv2.waitKey(10)
    if cv2.waitKey(1) & 0xFF == 27:
        break
            
#cap.release()
cv2.destroyAllWindows()
# Out:
# frame11320.jpg 2
# frame11460.jpg 2
# frame11560.jpg 2
# frame11640.jpg 2
# frame11660.jpg 2
# frame11700.jpg 2
# frame11760.jpg 2
# frame11780.jpg 2
# frame11820.jpg 2
# frame11860.jpg 2
# frame11900.jpg 2
# frame12020.jpg 2
# frame12060.jpg 2
# frame12120.jpg 2
# frame12400.jpg 2
# frame12480.jpg 2
# frame12680.jpg 2
# frame13180.jpg 2
# frame19200.jpg 2
# frame3700.jpg 2
# frame3720.jpg 2
# frame3740.jpg 2
# frame3760.jpg 2
# frame3780.jpg 2
# frame3800.jpg 2
# frame3820.jpg 2
# frame3840.jpg 2
# frame3860.jpg 2
# frame3880.jpg 2
# frame3900.jpg 2
# frame3920.jpg 2
# frame6820.jpg 2
# frame6840.jpg 2
# frame9300.jpg 2
# frame9420.jpg 2
# frame9440.jpg 2
# frame9540.jpg 2
# frame9660.jpg 2
# frame9680.jpg 2

# %%
import cv2
import mediapipe as mp

# Initialize MediaPipe face detection
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils
face_detection = mp_face_detection.FaceDetection(min_detection_confidence=0.5)

# Read the image/frame
frame = cv2.imread('C:\\Users\\99455\\Desktop\\DataScience\\Proctoring Task\\MoreThanOneFace\\frame12020.jpg')  # Or capture from video stream

# Convert frame to RGB (MediaPipe face detection works on RGB images)
rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# Detect faces
results = face_detection.process(rgb_frame)

# Filter out false positive detections and count the number of valid faces
num_faces = 0
if results.detections:
    for detection in results.detections:
        #bboxC = detection.location_data.relative_bounding_box
        #ih, iw, _ = frame.shape
        #bbox = int(bboxC.xmin * iw), int(bboxC.ymin * ih), int(bboxC.width * iw), int(bboxC.height * ih)
        
        bboxC = detection.location_data.relative_bounding_box
        ih, iw, _ = rgb_frame.shape
        bbox = int(bboxC.xmin * iw), int(bboxC.ymin * ih), int(bboxC.width * iw), int(bboxC.height * ih)
        cv2.rectangle(rgb_frame, bbox, (255, 0, 255), 2)
        #if bbox[2] * bbox[3] > 5000:  # Adjust this threshold as needed
        #    num_faces += 1
        #mp_drawing.draw_detection(frame, detection)
    #cv2.putText(image,x, (20,450), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0),2)  
    #cv2.putText(image,"file",(20,50), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0),2)
    #cv2.imshow("Face Detection", image) 

print("Number of faces detected:", num_faces)

# Display the result
cv2.imshow('Face Detection', rgb_frame)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Number of faces detected: 0

# %%
import cv2
import mediapipe as mp


mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils
face_detection = mp_face_detection.FaceDetection(min_detection_confidence=0.5)


path = "C:\\Users\\99455\\Desktop\\DataScience\\Proctoring Task\\MoreThanOneFace\\*.*"
for file in glob.glob(path):
    image = cv2.imread(file)
    image = cv2.cvtColor(cv2.flip(image,1), cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    
    rdet = face_detection.process(image)
    
    image.flags.writeable = True
    image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    
    old_path =  file
    filename = file.split('\\')[-1]
    

    x = "face detected"
    
        
    if len(rdet.detections) > 1:
        print(filename +' '+ str(len(rdet.detections)))
            #shutil.move(old_path, new_path)
    for detection in rdet.detections:

        bboxC = detection.location_data.relative_bounding_box
        ih, iw, _ = image.shape
        bbox = int(bboxC.xmin * iw), int(bboxC.ymin * ih), int(bboxC.width * iw), int(bboxC.height * ih)
        if bbox[2] * bbox[3] > 5000:  # Adjust this threshold as needed
            num_faces += 1
        cv2.rectangle(image, bbox, (255, 0, 255), 2)
        
        cv2.putText(image,x, (20,450), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0),2)  
        cv2.putText(image,filename,(20,50), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0),2)
        cv2.imshow("Face Detection", image)  
    cv2.waitKey(10)
    if cv2.waitKey(1) & 0xFF == 27:
        break
            
#cap.release()
cv2.destroyAllWindows()
# Out:
# frame11320.jpg 2
# frame11460.jpg 2
# frame11560.jpg 2
# frame11640.jpg 2
# frame11660.jpg 2
# frame11700.jpg 2
# frame11760.jpg 2
# frame11780.jpg 2
# frame11820.jpg 2
# frame11860.jpg 2
# frame11900.jpg 2
# frame12020.jpg 2
# frame12060.jpg 2
# frame12120.jpg 2
# frame12400.jpg 2
# frame12480.jpg 2
# frame12680.jpg 2
# frame13180.jpg 2
# frame19200.jpg 2
# frame3700.jpg 2
# frame3720.jpg 2
# frame3740.jpg 2
# frame3760.jpg 2
# frame3780.jpg 2
# frame3800.jpg 2
# frame3820.jpg 2
# frame3840.jpg 2
# frame3860.jpg 2
# frame3880.jpg 2
# frame3900.jpg 2
# frame3920.jpg 2
# frame6820.jpg 2
# frame6840.jpg 2
# frame9300.jpg 2
# frame9420.jpg 2
# frame9440.jpg 2
# frame9540.jpg 2
# frame9660.jpg 2
# frame9680.jpg 2
